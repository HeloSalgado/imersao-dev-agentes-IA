# %%
print("Heloisa")
# Out:
# Heloisa

# %%
saudacao = "Olá, mundo!"

# %%
saudacao
# Out:
# 'Olá, mundo!'

# %%
resposta = 'Não sei.'
resposta
# Out:
# 'Não sei.'

# %%
idade = 20
idade
# Out:
# 20

# %%
gasolina = 6.55
gasolina
# Out:
# 6.55

# %%
contexto_encontrado = True
contexto_encontrado
# Out:
# True

# %%
# Lista
citacoes = ['Frase 1', 'Frase 2', 'Frase 3']
citacoes
# Out:
# ['Frase 1', 'Frase 2', 'Frase 3']

# %%
valores = [42, 100, 1592]
valores
# Out:
# [42, 100, 1592]

# %%
valores[1]
# Out:
# 100

# %%
resultado_da_soma = valores[0] + valores[1]
resultado_da_soma
# Out:
# 142

# %%
# Dicionário
bandas_favoritas = {
    'banda_favorita': 'Banda 1',
    'banda_legalzinha': 'Banda 2',
}
bandas_favoritas
# Out:
# {'banda_favorita': 'Banda 1', 'banda_legalzinha': 'Banda 2'}

# %%
bandas_favoritas['banda_favorita']
# Out:
# 'Banda 1'

# %%
# Métodos
texto_sujo = "    olá   "
texto_limpo = texto_sujo.strip()
texto_limpo
# Out:
# 'olá'

# %%
# Condicional IF
idade = 16

if idade >= 18:
  print('Pode dirigir')
else:
  print('Não pode dirigir')
# Out:
# Não pode dirigir

# %%
# Comparações e lógica
x = 10
y = 5

igual = x == y
print("x é igual a y? ", igual)

diferente = not (x == y)
print("x é diferente de y? ", diferente)
# Out:
# x é igual a y?  False
# x é diferente de y?  True

# %%
# Funções
def saudar(nome: str) -> str:
  return f"Olá, {nome}!"

mensagem = saudar('Heloisa')
print(mensagem)
# Out:
# Olá, Heloisa!

# %%
def saudar():
  nome = input("Qual seu nome? ")
  return f"Olá, {nome}!"

mensagem = saudar()
print(mensagem)
# Out:
# Qual seu nome? ana
# Olá, ana!

# %%
from math import sqrt

sqrt(25)
# Out:
# 5.0
